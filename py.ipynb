# %%
import requests

url = "https://imdb236.p.rapidapi.com/api/imdb/cast/nm0000190/titles"

headers = {
	"x-rapidapi-key": "112581f03fmsh471313b0d1d9dbcp1e7886jsnb4937fef2242",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'id': 'tt27706593', 'url': 'https://www.imdb.com/title/tt27706593/', 'primaryTitle': 'The Rivals of Amziah King', 'originalTitle': 'The Rivals of Amziah King', 'type': 'movie', 'description': 'Kateri loses her mother, leaves foster care. Reunites with former foster parent Amziah who mentors her, revealing hidden skills. Faces devastating situation, relies on newfound strength to seek justice.', 'primaryImage': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcGc@.jpg', 'thumbnails': [{'url': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcGc@._V1_QL75_UX100_CR0,0,100,148_.jpg', 'width': 100, 'height': 148}, {'url': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcGc@._V1_QL75_UX280_CR0,0,280,414_.jpg', 'width': 280, 'height': 414}, {'url': 'https://m.media-amazon.com/images/M/MV5BODRhMTczNjgtMDcwNi00MDljLTkxN2ItYTFjOGJlMmIxY2U5XkEyXkFqcG
# ...

# %%
import pandas as pd

# %%
temp_df = pd.DataFrame(response.json())[['id','originalTitle','type','isAdult','releaseDate','runtimeMinutes','averageRating']]

# %%
temp_df.shape
# Out:
# (100, 7)

# %%
temp_df.to_csv('imdb_titles_uap.csv')
